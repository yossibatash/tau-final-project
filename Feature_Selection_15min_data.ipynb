# %% [markdown]
# # Feature_Selection

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from tensorflow import keras

# %%
# 1. Data Loading and Preparation
file_path = "./data/DWH/new_features_15min_csv/part-00000-610496dd-9da9-42b7-95ac-df9b2d3dffae-c000.csv"
df = pd.read_csv(file_path, index_col="t_trade_epoch", parse_dates=True)
# Out:
# /var/folders/zs/58cl69cn5vl0kg2h9gsyvnqw0000gq/T/ipykernel_27326/3004300032.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(file_path, index_col="t_trade_epoch", parse_dates=True)

# %%
df.info(True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17520 entries, 1641183300 to 1675454400
# Data columns (total 122 columns):
#  #    Column                                                Dtype
# ---   ------                                                -----
#  0    time                                                  object
#  1    open                                                  float64
#  2    high                                                  float64
#  3    low                                                   float64
#  4    close                                                 float64
#  5    volume                                                int64
#  6    t_trade_date                                          object
#  7    t_trade_hour                                          int64
#  8    t_trade_minute                                        int64
#  9    t_trade_day_of_week                                   int64
#  10   t_trade_open_e                                        int64
#  11   t_trade_open_h                                        int64
#  12   t_trade_close_e                                       int64
#  13   t_trade_close_h                                       int64
#  14   t_time_diff_between_trade_and_open_in_sec             int64
#  15   t_trade_part                                          int64
#  16   t_trade_part_open_e                                   int64
#  17   t_trade_part_open_h                                   int64
#  18   t_time_diff_between_trade_and_trade_part_open_in_sec  int64
#  19   t_precent_of_time_from_start_of_trade_pase            float64
#  20   t_precent_of_time_from_start_of_trade_day             float64
#  21   p_min_open_price_for_last_45min                       float64
#  22   p_avg_open_price_for_last_45min                       float64
#  23   p_max_open_price_for_last_45min                       float64
#  24   p_stddev_open_price_for_last_45min                    float64
#  25   p_min_open_price_for_last_75min                       float64
#  26   p_avg_open_price_for_last_75min                       float64
#  27   p_max_open_price_for_last_75min                       float64
#  28   p_stddev_open_price_for_last_75min                    float64
#  29   p_min_open_price_for_last_150min                      float64
#  30   p_avg_open_price_for_last_150min                      float64
#  31   p_max_open_price_for_last_150min                      float64
#  32   p_stddev_open_price_for_last_150min                   float64
#  33   p_min_high_price_for_last_45min                       float64
#  34   p_avg_high_price_for_last_45min                       float64
#  35   p_max_high_price_for_last_45min                       float64
#  36   p_stddev_high_price_for_last_45min                    float64
#  37   p_min_high_price_for_last_75min                       float64
#  38   p_avg_high_price_for_last_75min                       float64
#  39   p_max_high_price_for_last_75min                       float64
#  40   p_stddev_high_price_for_last_75min                    float64
#  41   p_min_high_price_for_last_150min                      float64
#  42   p_avg_high_price_for_last_150min                      float64
#  43   p_max_high_price_for_last_150min                      float64
#  44   p_stddev_high_price_for_last_150min                   float64
#  45   p_min_low_price_for_last_45min                        float64
#  46   p_avg_low_price_for_last_45min                        float64
#  47   p_max_low_price_for_last_45min                        float64
#  48   p_stddev_low_price_for_last_45min                     float64
#  49   p_min_low_price_for_last_75min                        float64
#  50   p_avg_low_price_for_last_75min                        float64
#  51   p_max_low_price_for_last_75min                        float64
#  52   p_stddev_low_price_for_last_75min                     float64
#  53   p_min_low_price_for_last_150min                       float64
#  54   p_avg_low_price_for_last_150min                       float64
#  55   p_max_low_price_for_last_150min                       float64
#  56   p_stddev_low_price_for_last_150min                    float64
#  57   p_min_close_price_for_last_45min                      float64
#  58   p_avg_close_price_for_last_45min                      float64
#  59   p_max_close_price_for_last_45min                      float64
#  60   p_stddev_close_price_for_last_45min                   float64
#  61   p_min_close_price_for_last_75min                      float64
#  62   p_avg_close_price_for_last_75min                      float64
#  63   p_max_close_price_for_last_75min                      float64
#  64   p_stddev_close_price_for_last_75min                   float64
#  65   p_min_close_price_for_last_150min                     float64
#  66   p_avg_close_price_for_last_150min                     float64
#  67   p_max_close_price_for_last_150min                     float64
#  68   p_stddev_close_price_for_last_150min                  float64
#  69   p_min_volume_price_for_last_45min                     int64
#  70   p_avg_volume_price_for_last_45min                     float64
#  71   p_max_volume_price_for_last_45min                     int64
#  72   p_stddev_volume_price_for_last_45min                  float64
#  73   p_min_volume_price_for_last_75min                     int64
#  74   p_avg_volume_price_for_last_75min                     float64
#  75   p_max_volume_price_for_last_75min                     int64
#  76   p_stddev_volume_price_for_last_75min                  float64
#  77   p_min_volume_price_for_last_150min                    int64
#  78   p_avg_volume_price_for_last_150min                    float64
#  79   p_max_volume_price_for_last_150min                    int64
#  80   p_stddev_volume_price_for_last_150min                 float64
#  81   snp_media_events_count                                int64
#  82   m_avg_snp_media_events_count_last_15min               float64
#  83   m_max_snp_media_events_count_last_15min               int64
#  84   m_stddev_snp_media_events_count_last_15min            float64
#  85   m_sum_snp_media_events_count_last_15min               int64
#  86   m_avg_snp_media_events_count_last_30min               float64
#  87   m_max_snp_media_events_count_last_30min               int64
#  88   m_stddev_snp_media_events_count_last_30min            float64
#  89   m_sum_snp_media_events_count_last_30min               int64
#  90   m_avg_snp_media_events_count_last_45min               float64
#  91   m_max_snp_media_events_count_last_45min               int64
#  92   m_stddev_snp_media_events_count_last_45min            float64
#  93   m_sum_snp_media_events_count_last_45min               int64
#  94   m_avg_snp_media_events_count_last_1hour               float64
#  95   m_max_snp_media_events_count_last_1hour               int64
#  96   m_stddev_snp_media_events_count_last_1hour            float64
#  97   m_sum_snp_media_events_count_last_1hour               int64
#  98   m_avg_snp_media_events_count_last_3hour               float64
#  99   m_max_snp_media_events_count_last_3hour               int64
#  100  m_stddev_snp_media_events_count_last_3hour            float64
#  101  m_sum_snp_media_events_count_last_3hour               int64
#  102  m_avg_snp_media_events_count_last_3days               float64
#  103  m_max_snp_media_events_count_last_3days               int64
#  104  m_stddev_snp_media_events_count_last_3days            float64
#  105  m_sum_snp_media_events_count_last_3days               int64
#  106  m_avg_snp_media_events_count_last_7days               float64
#  107  m_max_snp_media_events_count_last_7days               int64
#  108  m_stddev_snp_media_events_count_last_7days            float64
#  109  m_sum_snp_media_events_count_last_7days               int64
#  110  m_avg_snp_media_events_count_last_14days              float64
#  111  m_max_snp_media_events_count_last_14days              int64
#  112  m_stddev_snp_media_events_count_last_14days           float64
#  113  m_sum_snp_media_events_count_last_14days              int64
#  114  m_avg_snp_media_events_count_last_30days              float64
#  115  m_max_snp_media_events_count_last_30days              int64
#  116  m_stddev_snp_media_events_count_last_30days           float64
#  117  m_sum_snp_media_events_count_last_30days              int64
#  118  m_avg_snp_media_events_count_last_60days              float64
#  119  m_max_snp_media_events_count_last_60days              int64
#  120  m_stddev_snp_media_events_count_last_60days           float64
#  121  m_sum_snp_media_events_count_last_60days              int64
# dtypes: float64(80), int64(40), object(2)
# memory usage: 16.4+ MB

# %%
# 2. Feature Selection

all_features = ['open',
                'high',
'low',
'volume',  
't_trade_hour',  
't_trade_minute',  
't_trade_day_of_week',  
't_trade_open_e',  
't_trade_open_h',  
't_trade_close_e',  
't_trade_close_h',  
't_time_diff_between_trade_and_open_in_sec',  
't_trade_part',  
't_trade_part_open_e',  
't_trade_part_open_h',  
't_time_diff_between_trade_and_trade_part_open_in_sec',  
't_precent_of_time_from_start_of_trade_pase',
't_precent_of_time_from_start_of_trade_day',
'p_min_open_price_for_last_45min',
'p_avg_open_price_for_last_45min',
'p_max_open_price_for_last_45min',
'p_stddev_open_price_for_last_45min',
'p_min_open_price_for_last_75min',
'p_avg_open_price_for_last_75min',
'p_max_open_price_for_last_75min',
'p_stddev_open_price_for_last_75min',
'p_min_open_price_for_last_150min',
'p_avg_open_price_for_last_150min',
'p_max_open_price_for_last_150min',
'p_stddev_open_price_for_last_150min',
'p_min_high_price_for_last_45min',
'p_avg_high_price_for_last_45min',
'p_max_high_price_for_last_45min',
'p_stddev_high_price_for_last_45min',
'p_min_high_price_for_last_75min',
'p_avg_high_price_for_last_75min',
'p_max_high_price_for_last_75min',
'p_stddev_high_price_for_last_75min',
'p_min_high_price_for_last_150min',
'p_avg_high_price_for_last_150min',
'p_max_high_price_for_last_150min',
'p_stddev_high_price_for_last_150min',
'p_min_low_price_for_last_45min',
'p_avg_low_price_for_last_45min',
'p_max_low_price_for_last_45min',
'p_stddev_low_price_for_last_45min',
'p_min_low_price_for_last_75min',
'p_avg_low_price_for_last_75min',
'p_max_low_price_for_last_75min',
'p_stddev_low_price_for_last_75min',
'p_min_low_price_for_last_150min',
'p_avg_low_price_for_last_150min',
'p_max_low_price_for_last_150min',
'p_stddev_low_price_for_last_150min',
'p_min_close_price_for_last_45min',
'p_avg_close_price_for_last_45min',
'p_max_close_price_for_last_45min',
'p_stddev_close_price_for_last_45min',
'p_min_close_price_for_last_75min',
'p_avg_close_price_for_last_75min',
'p_max_close_price_for_last_75min',
'p_stddev_close_price_for_last_75min',
'p_min_close_price_for_last_150min',
'p_avg_close_price_for_last_150min',
'p_max_close_price_for_last_150min',
'p_stddev_close_price_for_last_150min',
'p_min_volume_price_for_last_45min',  
'p_avg_volume_price_for_last_45min',
'p_max_volume_price_for_last_45min',  
'p_stddev_volume_price_for_last_45min',
'p_min_volume_price_for_last_75min',  
'p_avg_volume_price_for_last_75min',
'p_max_volume_price_for_last_75min',  
'p_stddev_volume_price_for_last_75min',
'p_min_volume_price_for_last_150min',  
'p_avg_volume_price_for_last_150min',
'p_max_volume_price_for_last_150min',  
'p_stddev_volume_price_for_last_150min',
'snp_media_events_count',  
'm_avg_snp_media_events_count_last_15min',
'm_max_snp_media_events_count_last_15min',  
'm_stddev_snp_media_events_count_last_15min',
'm_sum_snp_media_events_count_last_15min',  
'm_avg_snp_media_events_count_last_30min',
'm_max_snp_media_events_count_last_30min',  
'm_stddev_snp_media_events_count_last_30min',
'm_sum_snp_media_events_count_last_30min',  
'm_avg_snp_media_events_count_last_45min',
'm_max_snp_media_events_count_last_45min',  
'm_stddev_snp_media_events_count_last_45min',
'm_sum_snp_media_events_count_last_45min',  
'm_avg_snp_media_events_count_last_1hour',
'm_max_snp_media_events_count_last_1hour',  
'm_stddev_snp_media_events_count_last_1hour',
'm_sum_snp_media_events_count_last_1hour',  
'm_avg_snp_media_events_count_last_3hour',
'm_max_snp_media_events_count_last_3hour',  
'm_stddev_snp_media_events_count_last_3hour',
'm_sum_snp_media_events_count_last_3hour',  
'm_avg_snp_media_events_count_last_3days',
'm_max_snp_media_events_count_last_3days',  
'm_stddev_snp_media_events_count_last_3days',
'm_sum_snp_media_events_count_last_3days',  
'm_avg_snp_media_events_count_last_7days',
'm_max_snp_media_events_count_last_7days',  
'm_stddev_snp_media_events_count_last_7days',
'm_sum_snp_media_events_count_last_7days',  
'm_avg_snp_media_events_count_last_14days',
'm_max_snp_media_events_count_last_14days',  
'm_stddev_snp_media_events_count_last_14days',
'm_sum_snp_media_events_count_last_14days',  
'm_avg_snp_media_events_count_last_30days',
'm_max_snp_media_events_count_last_30days',  
'm_stddev_snp_media_events_count_last_30days',
'm_sum_snp_media_events_count_last_30days',  
'm_avg_snp_media_events_count_last_60days',
'm_max_snp_media_events_count_last_60days',  
'm_stddev_snp_media_events_count_last_60days',
'm_sum_snp_media_events_count_last_60days'] 

# 1. Fill NaN values with 0
data = df[all_features].fillna(0)

# 2. Scale the features
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(data.values)
scaled_features = pd.DataFrame(scaled_features, index = data.index, columns=data.columns)

# 3. Apply PCA
pca = PCA(n_components=0.95)  # Keep components explaining 95% of variance
pca.fit(scaled_features)
pca_features = pca.transform(scaled_features)

# %%
# Correct the column assignment, rename the columns so that they are named PC1, PC2, ...
pca_features = pd.DataFrame(pca_features, index = scaled_features.index, columns=[f"PC{i+1}" for i in range(pca_features.shape[1])])

# %%
# --- Analyze Loadings  ---
loadings = pd.DataFrame(pca.components_.T, index=all_features, columns = [f"PC{i+1}" for i in range(pca_features.shape[1])])

# %%
loadings
# Out:
#                                                   PC1       PC2       PC3  \
# open                                         0.109938 -0.025026 -0.075933
# high                                         0.110042 -0.024634 -0.075583
# low                                          0.109011 -0.025188 -0.075505
# volume                                       0.003417 -0.015085  0.006224
# t_trade_hour                                -0.000146 -0.324189  0.164752
# ...                                               ...       ...       ...
# m_sum_snp_media_events_count_last_30days    -0.224171 -0.016357 -0.052752
# m_avg_snp_media_events_count_last_60days    -0.242141  0.001041 -0.006982
# m_max_snp_media_events_count_last_60days    -0.233608 -0.018553 -0.058477
# m_stddev_snp_media_events_count_last_60days -0.225983 -0.027708 -0.086818
# m_sum_snp_media_events_count_last_60days    -0.242141  0.001041 -0.006982
#
#                                                   PC4       PC5       PC6  \
# open                                         0.136202  0.067883  0.101916
# high                                         0.137127  0.067235  0.102192
# low                                          0.134412  0.068050  0.100792
# volume                                       0.015748 -0.012626  0.000746
# t_trade_hour                                -0.071070 -0.053868  0.099699
# ...                                               ...       ...       ...
# m_sum_snp_media_events_count_last_30days    -0.011312  0.012227 -0.022256
# m_avg_snp_media_events_count_last_60days    -0.134208 -0.024556 -0.103552
# m_max_snp_media_events_count_last_60days    -0.002004  0.050271  0.020465
# m_stddev_snp_media_events_count_last_60days  0.049070  0.094454  0.079119
# m_sum_snp_media_events_count_last_60days    -0.134208 -0.024556 -0.103552
#
#                                                   PC7       PC8       PC9  \
# open                                        -0.000820 -0.112430  0.233765
# high                                        -0.000427 -0.107725  0.231193
# low                                         -0.001094 -0.116047  0.234539
# volume                                      -0.003952  0.094898 -0.025252
# t_trade_hour                                -0.013311 -0.080570 -0.055048
# ...                                               ...       ...       ...
# m_sum_snp_media_events_count_last_30days    -0.014560 -0.034088 -0.077263
# m_avg_snp_media_events_count_last_60days    -0.022604  0.006276 -0.159284
# m_max_snp_media_events_count_last_60days    -0.004494 -0.015084 -0.003967
# m_stddev_snp_media_events_count_last_60days  0.000826 -0.047961  0.014028
# m_sum_snp_media_events_count_last_60days    -0.022604  0.006276 -0.159284
#
#                                                  PC10      PC11
# open                                        -0.022829 -0.407858
# high                                        -0.022106 -0.408032
# low                                         -0.023099 -0.404847
# volume                                       0.012640 -0.054026
# t_trade_hour                                 0.019803 -0.030158
# ...                                               ...       ...
# m_sum_snp_media_events_count_last_30days    -0.284844 -0.135889
# m_avg_snp_media_events_count_last_60days    -0.360254 -0.010237
# m_max_snp_media_events_count_last_60days     0.005389 -0.035502
# m_stddev_snp_media_events_count_last_60days -0.116397 -0.132183
# m_sum_snp_media_events_count_last_60days    -0.360254 -0.010237
#
# [119 rows x 11 columns]

# %%
top_n = 20
selected_features = set()
for i in range(pca_features.shape[1]): # for each principal component
    component_loadings = loadings[f"PC{i+1}"].abs()
    top_features = component_loadings.nlargest(top_n).index
    selected_features.update(top_features) # This line is important, it adds multiple feature to the set
selected_features = list(selected_features)

# I played with top_n values until I managed to reduce the selected_features to ~ 50%  
print(f"Count of selected_features - {len(selected_features)}")
print(selected_features)
# Out:
# Count of selected_features - 86
# ['p_max_low_price_for_last_150min', 't_trade_part_open_h', 'm_sum_snp_media_events_count_last_7days', 'm_stddev_snp_media_events_count_last_14days', 'm_stddev_snp_media_events_count_last_3hour', 'p_max_close_price_for_last_150min', 'p_max_low_price_for_last_45min', 'm_avg_snp_media_events_count_last_3hour', 'm_max_snp_media_events_count_last_30days', 'p_max_high_price_for_last_75min', 'p_avg_volume_price_for_last_45min', 'm_sum_snp_media_events_count_last_14days', 'p_avg_close_price_for_last_150min', 'p_stddev_low_price_for_last_75min', 'm_sum_snp_media_events_count_last_60days', 'p_min_high_price_for_last_150min', 'p_stddev_close_price_for_last_150min', 'm_max_snp_media_events_count_last_60days', 'm_avg_snp_media_events_count_last_60days', 'p_max_high_price_for_last_45min', 'p_max_low_price_for_last_75min', 'p_min_close_price_for_last_150min', 't_time_diff_between_trade_and_open_in_sec', 'p_stddev_high_price_for_last_75min', 'p_avg_volume_price_for_last_75min', 'p_stddev_high_price_for_last_150min', 'p_stddev_close_price_for_last_75min', 'm_stddev_snp_media_events_count_last_3days', 'p_stddev_open_price_for_last_150min', 'm_sum_snp_media_events_count_last_30days', 'p_max_high_price_for_last_150min', 'open', 'p_min_volume_price_for_last_150min', 't_trade_minute', 'low', 'm_sum_snp_media_events_count_last_1hour', 'm_max_snp_media_events_count_last_14days', 'm_avg_snp_media_events_count_last_14days', 't_trade_part_open_e', 'p_avg_low_price_for_last_150min', 'm_stddev_snp_media_events_count_last_1hour', 'p_max_close_price_for_last_75min', 'p_avg_high_price_for_last_75min', 'm_stddev_snp_media_events_count_last_60days', 'm_avg_snp_media_events_count_last_1hour', 'm_stddev_snp_media_events_count_last_30days', 'p_min_volume_price_for_last_75min', 'p_max_open_price_for_last_150min', 'p_avg_close_price_for_last_75min', 'p_min_open_price_for_last_150min', 'p_avg_open_price_for_last_75min', 'p_stddev_open_price_for_last_75min', 't_trade_close_e', 'p_min_low_price_for_last_150min', 'm_max_snp_media_events_count_last_3hour', 'm_avg_snp_media_events_count_last_7days', 't_trade_hour', 't_time_diff_between_trade_and_trade_part_open_in_sec', 'p_stddev_low_price_for_last_150min', 'm_sum_snp_media_events_count_last_3hour', 'p_max_volume_price_for_last_150min', 'p_avg_high_price_for_last_150min', 'm_sum_snp_media_events_count_last_3days', 'p_max_volume_price_for_last_75min', 'm_max_snp_media_events_count_last_7days', 'm_avg_snp_media_events_count_last_45min', 'p_min_volume_price_for_last_45min', 'p_max_open_price_for_last_75min', 'm_avg_snp_media_events_count_last_30days', 'p_avg_open_price_for_last_150min', 'p_avg_volume_price_for_last_150min', 't_trade_part', 'p_min_open_price_for_last_75min', 't_precent_of_time_from_start_of_trade_day', 'm_max_snp_media_events_count_last_3days', 'm_sum_snp_media_events_count_last_45min', 'p_max_volume_price_for_last_45min', 't_trade_open_e', 'm_avg_snp_media_events_count_last_3days', 'high', 'p_stddev_volume_price_for_last_75min', 'm_stddev_snp_media_events_count_last_7days', 't_trade_day_of_week', 't_precent_of_time_from_start_of_trade_pase', 'p_max_open_price_for_last_45min', 'snp_media_events_count']
